# %% [markdown]
# #Oppgave 1,

# %%
#Beregner hvor gammel er person som ble 2024

alder= int(input('Hvilket år ble du født?'))
år = 2024-alder
print('Du ble', år, 'i 2024')
# Out:
# Hvilket år ble du født? 2781
# Du ble -757 i 2024

# %% [markdown]
# # Oppgave 2,

# %%
#Beregner hvor mange pizzar som må kjøpes inn

antall_elever = int(input('Hvor mange elever kommer?'))

pizza = round(antall_elever / 4)

print('Det må handles inn', pizza, 'pizzaer til festen')
# Out:
# Hvor mange elever kommer? 44
# Det må handles inn 11 pizzaer til festen

# %% [markdown]
# # Oppgave 3,

# %%
#En funskjon som beregner grader til radianer

import numpy as np

v_grad = float(input('Skriv inn gradtallet:'))

v_rad= v_grad*np.pi/180


print('Radiantallet er', v_rad)
# Out:
# Skriv inn gradtallet: 5
# Radiantallet er 0.08726646259971647

# %% [markdown]
# #Oppgave 4

# %%
# a) Opprettelse av dictionary
landsinfo = {
    "Norge": {"hovedstad": "Oslo", "innbyggere": 0.693},
    "Sverige": {"hovedstad": "Stockholm", "innbyggere": 0.975},
    "England": {"hovedstad": "London", "innbyggere": 8.982},
    "Tyskland": {"hovedstad": "Berlin", "innbyggere": 3.769},
}

# b) Program som skriver ut informasjon om et land
land = input("Skriv inn et land: ")
if land in landsinfo:
    hovedstad = landsinfo[land]["hovedstad"]
    innbyggere = landsinfo[land]["innbyggere"]
    print(f"{hovedstad} er hovedstaden i {land} og det er {innbyggere} mill. innbyggere i {hovedstad}")
else:
    print(f"Informasjon om {land} finnes ikke i databasen.")

# c) Program for å legge til nytt land
nytt_land = input("Skriv inn navnet på et nytt land: ")
if nytt_land not in landsinfo:
    hovedstad = input(f"Hva er hovedstaden i {nytt_land}? ")
    innbyggere = float(input(f"Hvor mange millioner innbyggere bor det i {hovedstad}? "))
    landsinfo[nytt_land] = {"hovedstad": hovedstad, "innbyggere": innbyggere}
    print("Landet er lagt til i databasen. Oppdatert dictionary:")
    print(landsinfo)
else:
    print(f"{nytt_land} finnes allerede i databasen.")
# Out:
# Skriv inn et land:  Norge
# Oslo er hovedstaden i Norge og det er 0.693 mill. innbyggere i Oslo
# Skriv inn navnet på et nytt land:  Norge
# Norge finnes allerede i databasen.

# %% [markdown]
# # Oppgave 5,

# %%
# Importerer nødvendige biblioteker
import numpy as np
import matplotlib.pyplot as plt
import math

# Funksjon for areal og ytre omkrets
def calculate_area_and_perimeter(a, b):
    """
    Beregner arealet og ytre omkrets av en figur som består av 
    en rettvinklet trekant og en halvsirkel.
    
    Args:
        a (float): Grunnlinje til trekanten.
        b (float): Høyde til trekanten.

    Returns:
        tuple: Arealet og ytre omkrets av figuren.
    """
    # Beregner arealet av trekanten og halvsirkelen
    triangle_area = (a * b) / 2
    radius = math.sqrt(a**2 + b**2) / 2
    semicircle_area = (math.pi * radius**2) / 2
    total_area = triangle_area + semicircle_area

    # Beregner ytre omkrets (omkrets av sorte linjer)
    hypotenuse = math.sqrt(a**2 + b**2)
    semicircle_perimeter = math.pi * radius
    total_perimeter = a + b + hypotenuse + semicircle_perimeter

    return total_area, total_perimeter

a = input('Hvor lang er grunnlinjen til trekanten?')
b = input('Hva er høyden på trekanten?')

print(f"Arealet av figuren er: {area:.2f}")
print(f"Ytre omkrets av figuren er: {perimeter:.2f}")
# Out:
# Hvor lang er grunnlinjen til trekanten? 5
# Hva er høyden på trekanten? 12
# Arealet av figuren er: 96.37
# Ytre omkrets av figuren er: 50.42

# %% [markdown]
# # Oppgave 6,

# %%
def plot_function():
    """
    Plotter funksjonen f(x) = -x^2 - 5 for x i intervallet [-10, 10].
    """
    x = np.linspace(-10, 10, 200)
    y = -x**2 - 5

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label="$f(x) = -x^2 - 5$", color="blue")
    plt.title("Plot av funksjonen $f(x) = -x^2 - 5$", fontsize=14)
    plt.xlabel("x", fontsize=12)
    plt.ylabel("f(x)", fontsize=12)
    plt.axhline(0, color="black", linewidth=0.5, linestyle="--")
    plt.axvline(0, color="black", linewidth=0.5, linestyle="--")
    plt.grid(color="gray", linestyle="--", linewidth=0.5)
    plt.legend(fontsize=12)
    plt.show()

# Plot funksjonen
plot_function()
